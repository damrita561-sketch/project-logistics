# %%
# %sql
create schema bronze.logistic;

# %%
# %sql
create or replace TABLE bronze.logistic.SALES_DATA_PRIOR_DAY (
	YARD_ID string,
	YARD string,
	MATERIAL_NAME string,
	MATERIAL_CODE string,
	COMMODITY_NAME string,
	COMMODITY_TYPE string,
	OUTBOUND_TICKET_ID string,
	LATEST_SHIP_DATE string,
	LATEST_PAYMENT_DATE string,
	INVOICE_ISSUE_DATE string,
	INVOICE_STATUS string,
	INVOICE_NOTES string,
	CUSTOMER_NAME string,
	SALES_ORDER_ID string,
	OUTBOUND_TICKET_STATUS string,
	INVOICE_ID string,
	TAX_RATE string,
	CONSUMER_GROSS string,
	CONSUMER_TARE string,
	CONSUMER_NET_WEIGHT string,
	UM string,
	PRICE string,
	SELL_PRICE string,
	INVOICE_SUBTOTAL string,
	INVOICE_TOTAL string,
	INVOICE_FREIGHT_TOTAL string,
	AMOUNT_PAID string,
	PAYMENT_ADJUSTMENTS string,
	INVOICE_GRAND_TOTAL string,
	INVOICE_BALANCE_REMAINING string,
	COST_OF_GOODS_SOLD string,
	GROSS_MARGIN_DOLLAR string,
	MARGIN_PERCENTAGE string,
	NET_WEIGHT_SOLD string,
	WEIGHT_DIFFERENTIAL string,
	CURRENCY string,
	ACCOUNT_MANAGER string,
	CONVERTED_TOTAL string,
	IS_EXPORT string,
	MILL_SCALE_NUMBER string,
	ADDED_BY string,
	ADDED_ON timestamp
);

# %%
# %sql
create or replace TABLE bronze.logistic.APPOINTMENT_DATA (
	YARD_NAME string,
	APPOINTMENT_NUMBER string,
	APPOINTMENT_TITLE string,
	REFERENCE_TYPE string,
	SALES_ORDER_TICKET_ID string,
	PURCHASE_ORDER_TICKET_ID string,
	INBOUND_TICKET_ID string,
	OUTBOUND_TICKET_ID string,
	CUSTOMER_ID string,
	CUSTOMER_NAME string,
	CARRIER_NAME string,
	DRIVER_NAME string,
	ORDER_FULFILLED string,
	APPOINTMENT_STATUS string,
	SCHEDULED_START string,
	SCHEDULED_END string,
	SHIPMENT_TYPE string,
	VESSEL string,
	SHIPPING_LINE_NAME string,
	FORWARDER_NVOCC string,
	ESTIMATED_TIME_OF_ARRIVAL string,
	ESTIMATED_TIME_OF_DEPARTURE string,
	EARLIEST_RETURN_DATE string,
	DOCUMENTATION_CUTOFF_DEADLINE string,
	CARGO_CUTOFF_DEADLINE string,
	EXPORT_REFERENCE_NUMBER string,
	CONTAINER_TYPE string,
	NUMBER_OF_CONTAINERS string,
	VOYAGE string,
	SCHEDULED_DURATION_HOURS string,
	APPOINTMENT_DATE string,
	DAY_OF_WEEK string,
	IS_FUTURE string,
	IS_ACTIVE string,
	CREATED_AT string,
	CREATED_BY string,
	CREATED_BY_EMAIL string,
	UPDATED_AT string,
	UPDATED_BY string,
	UPDATED_BY_EMAIL string,
	ADDED_BY string,
	ADDED_ON timestamp
);
